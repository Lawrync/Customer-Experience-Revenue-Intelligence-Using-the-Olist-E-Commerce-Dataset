# %% [markdown]
# WEEK 1: PROJECT FOUNDATION
# Project
#
# Customer Experience & Revenue Intelligence Using the Olist E-Commerce Dataset
#
# Objective of Week 1:
# By the end of the week, you should have:
#
# Understood the business problem.
# Loaded and explored all datasets.
# Cleaned the data.
# Merged the tables.
# Completed exploratory data analysis (EDA).
# Identified initial business insights.
# Prepared the dataset for Power BI.
# Monday – Business Understanding & Data Exploration
# Goal
#
# Understand the business before writing analysis.
#
# Python Concepts
# read_csv()
# shape
# head()
# tail()
# info()
# describe()
# isnull()
# Tasks
# Create the project structure.
# Load all datasets.
# Inspect each table.
# Create a data dictionary.
# Draw the relationship between tables.
# Write 20 business questions.
# Deliverables
# 01_Project_Setup.ipynb
# Business Understanding document
# Data Dictionary
# Data Model Diagram
# README.md
# Tuesday – Data Cleaning
# Goal
#
# Transform raw data into analysis-ready data.
#
# Python Concepts
# Missing values
# Duplicates
# Data types
# fillna()
# dropna()
# drop_duplicates()
# astype()
# to_datetime()
# Tasks
# Handle missing values.
# Remove duplicates.
# Convert dates.
# Standardize column names.
# Validate each dataset.
# Save cleaned datasets.
# Deliverables
# 02_Data_Cleaning.ipynb
# Cleaned CSV files
# Data Quality Report
# Wednesday – Data Integration & Feature Engineering
# Goal
#
# Create one analysis-ready dataset.
#
# Python Concepts
# merge()
# join()
# concat()
# groupby()
# transform()
# Feature engineering
# Create New Columns
# Delivery Days
# Late Delivery
# Order Value
# Order Month
# Order Year
# Customer Region
# Review Category
# Deliverables
# Master dataset
# Relationship validation
# Feature Engineering notebook
# Thursday – Exploratory Data Analysis (EDA)
# Goal
#
# Discover patterns and answer business questions.
#
# Python Concepts
# groupby()
# Aggregation
# Pivot tables
# Correlation
# Visualization
# Analyze
# Revenue by state
# Revenue by category
# Top sellers
# Worst sellers
# Delivery time
# Review scores
# Payment methods
# Monthly sales trends
# Deliverables
# EDA notebook
# 10–15 charts
# Initial insights
# Friday – Root Cause Analysis
# Goal
#
# Move beyond describing the data to explaining why things happen.
#
# Python Concepts
# Correlation
# Cross-tabulation
# Statistical summaries
# Business storytelling
# Investigate
# Does delivery delay reduce review scores?
# Which sellers cause most delays?
# Which categories have poor reviews?
# Does freight cost affect ratings?
# Which states have the longest deliveries?
# Deliverables
# Root Cause Analysis notebook
# Business insights document
# Saturday – KPI Development
# Goal
#
# Create metrics that don't exist in the original dataset.
#
# Build
# Customer Satisfaction Score
#
# Combine:
#
# Review score
# Delivery performance
# Repeat purchases
# Seller Performance Index
#
# Combine:
#
# Revenue
# Delivery reliability
# Review score
# Delivery Reliability Score
#
# Measure on-time performance.
#
# Revenue at Risk
#
# Estimate revenue linked to poor customer experience.
#
# Deliverables
# KPI notebook
# KPI documentation
# Sunday – Executive Summary & Project Review
# Goal
#
# Prepare for dashboard development.
#
# Write
# Executive Summary
# Key findings
# Recommendations
# Project roadmap for Week 2
# Create
# Folder cleanup
# GitHub update
# README improvements
# Deliverables
# Executive Summary
# Updated GitHub repository
# Week 1 presentation
# Daily Routine (3:00 AM – 6:00 AM)
# Time	Activity
# 3:00–3:10	Plan the day's objective
# 3:10–4:10	Python coding
# 4:10–4:20	Short break
# 4:20–5:20	Continue analysis
# 5:20–5:40	Document insights
# 5:40–6:00	Commit to GitHub and plan tomorrow
# Rules for This Project
# Never skip documentation.
# Comment your code.
# Every chart must answer a business question.
# Every finding must include a recommendation.
# Every recommendation should explain the expected business impact.
# Commit your work to GitHub at the end of each day.
# Week 2 Preview
#
# Next week we'll focus on turning the analysis into decision-making tools:
#
# Advanced feature engineering
# Statistical analysis
# Customer segmentation
# Seller segmentation
# Predictive analytics (optional)
# Power BI dashboard design
# Executive reporting
# End Goal
#
# By the end of this project, you won't just have another dashboard—you'll have a consulting-style portfolio piece that you can confidently discuss in interviews:
#
# Customer Experience & Revenue Intelligence: Identifying Operational Bottlenecks and Their Business Impact in an E-Commerce Marketplace
#
# This demonstrates technical skills, analytical thinking, and the ability to communicate actionable business insights—exactly what hiring managers look for in a data analyst.
